# %% [markdown]
# <a href="https://colab.research.google.com/github/rehammahal/COVID-19-project/blob/main/DataWrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pn
import numpy as np

path = "COVID19-project.xlsx"

covidData = pn.read_excel(path)

#Before
print("------------ Dataset Before Wrangling------------")
print(covidData)

#Check All Data Types
print("------------ Check All Data Types ------------")
print(covidData.dtypes)

#Check All Statisical Matric of Dataset
print("------------ Check All Statisical Matric of Dataset ------------")
print(covidData.describe(include="all"))

#Drop Daily\Cumulative and Event Attributes
new_covidData = covidData.drop('Event', axis = 'columns', inplace = True)
new_covidData = covidData.drop('Daily / Cumulative', axis = 'columns', inplace = True)
## AnotherWay---> new_covidData = covidData[['Indicator', 'Date', 'region', 'City', 'Cases']]

#Drop Records We Don't Need
new_covidData = covidData.drop(range(1277,30873), axis = 'rows', inplace = True)

#Drop Total Records
new_covidData = covidData[covidData["City"].str.contains("Total")==False]
#AnotherWays: 1--> new_covidData = new_covidData.drop(new_covidData[(new_covidData.region == "Total")].index)   2--> new_covidData = new_covidData[new_covidData.region != "Total"]

#Change Wrong Format in Dataset
new_covidData["Cases"].replace("?", np.nan, inplace = True) 
new_covidData["Cases"] = new_covidData["Cases"].astype('float64')
#AnotherWays: 1--> new_covidData = new_covidData.drop(new_covidData[(new_covidData.Cases == "?")].index) 2--> new_covidData.isnull().sum() COMMENT: To delet all False or null values

#Save New Data Frame after Changing
new_covidData.to_excel("newCleaningCOVID19.xlsx")

#Check All Statisical Matric of Dataset After Wrangling
print("------------ Check All Statisical Matric of Dataset ------------")
print(new_covidData.describe(include="all"))

#After
print("------------ Dataset After Wrangling ------------")
print(new_covidData)

#Descriptive Statistical
print("------------ Descriptive Statstical ------------")
new_covidData_case = new_covidData['Indicator'].value_counts()
new_covidData_case.rename(index = {'Indicator' : 'Items'}, inplace = True)
new_covidData_case.index.rename = 'Indicator'
print(new_covidData_case)

#DataFrame for Descriptive Statistical
new_covidData_case1 = new_covidData[new_covidData.Indicator =="Cases"].agg(["sum"])
new_covidData_case2 = new_covidData[new_covidData.Indicator =="Recoveries"].agg(["sum"])
new_covidData_case3 = new_covidData[new_covidData.Indicator =="Mortalities"].agg(["sum"])
print("------------ DataFrame for Descriptive Statistical ------------")
DF = {'Cases': new_covidData_case1["Cases"], 'Recoveries': new_covidData_case2["Cases"], 'Mortalities': new_covidData_case3["Cases"]}
new_covidData_case_final = pn.DataFrame(DF)
new_covidData_case_final.rename(index= {'sum':'Total'}, inplace = True)
print(new_covidData_case_final)

#Groping Data
print("------------ Groping Data for Type of Cases and Regions ------------")
Group_By = new_covidData[['Indicator', 'region', 'Cases']]
Group_By_Test = Group_By.groupby(["Indicator", "region"], as_index = False).sum()
print(Group_By_Test)
print("------------ Groping Data for Type of Cases and Regions as Povit Style ------------")
Group_By_Test_P = Group_By_Test.pivot(index = 'Indicator', columns = 'region')
print(Group_By_Test_P)
# Out:
# ------------ Dataset Before Wrangling------------
#       Daily / Cumulative     Indicator  ...                        City Cases
# 0                  Daily         Cases  ...                       Qatif     1
# 1                  Daily         Cases  ...                       Qatif     1
# 2                  Daily         Cases  ...                       Qatif     2
# 3                  Daily         Cases  ...                       Total     4
# 4                  Daily         Cases  ...                      Dammam     4
# ...                  ...           ...  ...                         ...   ...
# 30868         Cumulative  Active cases  ...             Hazm Al Jalamid    18
# 30869         Cumulative  Active cases  ...  Al Hadithah Border Station     5
# 30870         Cumulative  Active cases  ...                   Al Aydabi     1
# 30871         Cumulative  Active cases  ...                       Umluj    26
# 30872         Cumulative  Active cases  ...                       Bqeeq    41
#
# [30873 rows x 7 columns]
# ------------ Check All Data Types ------------
# Daily / Cumulative            object
# Indicator                     object
# Date                  datetime64[ns]
# Event                         object
# region                        object
# City                          object
# Cases                         object
# dtype: object
# ------------ Check All Statisical Matric of Dataset ------------
#        Daily / Cumulative Indicator  ...   City    Cases
# count               30873     30873  ...  30867  30865.0
# unique                  2         5  ...    188   2156.0
# top            Cumulative     Cases  ...  Total      1.0
# freq                24440     12534  ...    713   6334.0
# first                 NaN       NaN  ...    NaN      NaN
# last                  NaN       NaN  ...    NaN      NaN
#
# [6 rows x 7 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ------------ Check All Statisical Matric of Dataset ------------
#        Indicator                 Date          region    City        Cases
# count       1226                 1226            1226    1226  1219.000000
# unique         4                   94              13     156          NaN
# top        Cases  2020-06-11 00:00:00  Eastern Region  Jeddah          NaN
# freq         688                   43             284      47          NaN
# first        NaN  2020-03-02 00:00:00             NaN     NaN          NaN
# last         NaN  2020-06-13 00:00:00             NaN     NaN          NaN
# mean         NaN                  NaN             NaN     NaN    35.018868
# std          NaN                  NaN             NaN     NaN   111.620937
# min          NaN                  NaN             NaN     NaN     1.000000
# 25%          NaN                  NaN             NaN     NaN     1.000000
# 50%          NaN                  NaN             NaN     NaN     3.000000
# 75%          NaN                  NaN             NaN     NaN    13.000000
# max          NaN                  NaN             NaN     NaN  1499.000000
# ------------ Dataset After Wrangling ------------
#          Indicator       Date          region       City  Cases
# 0            Cases 2020-03-02  Eastern Region      Qatif    1.0
# 1            Cases 2020-03-04  Eastern Region      Qatif    1.0
# 2            Cases 2020-03-07  Eastern Region      Qatif    2.0
# 4            Cases 2020-03-10  Eastern Region     Dammam    4.0
# 5            Cases 2020-03-12           Mecca      Mecca   21.0
# ...            ...        ...             ...        ...    ...
# 1271   Mortalities 2020-06-13           Jazan      Sabya    1.0
# 1272   Mortalities 2020-06-13          Riyadh  Huraymila    1.0
# 1273   Mortalities 2020-06-13           Jazan      Baish    1.0
# 1274  Active cases 2020-03-02  Eastern Region      Qatif    1.0
# 1276  Active cases 2020-03-07  Eastern Region      Qatif    7.0
#
# [1226 rows x 5 columns]
# ------------ Descriptive Statstical ------------
# Cases           688
# Recoveries      467
# Mortalities      69
# Active cases      2
# Name: Indicator, dtype: int64
# ------------ DataFrame for Descriptive Statistical ------------
#          Cases  Recoveries  Mortalities
# Total  24773.0     17704.0        203.0
# ------------ Groping Data for Type of Cases and Regions ------------
#        Indicator            region   Cases
# 0   Active cases    Eastern Region     8.0
# 1          Cases          Al Bahah    48.0
# 2          Cases           Al Jouf    17.0
# 3          Cases              Asir   348.0
# 4          Cases    Eastern Region  5361.0
# 5          Cases              Hail   134.0
# 6          Cases             Jazan   454.0
# 7          Cases             Mecca  8286.0
# 8          Cases            Medina  1806.0
# 9          Cases            Najran    86.0
# 10         Cases  Northern Borders    48.0
# 11         Cases            Qassim   395.0
# 12         Cases            Riyadh  7639.0
# 13         Cases             Tabuk   151.0
# 14   Mortalities              Asir     2.0
# 15   Mortalities    Eastern Region    11.0
# 16   Mortalities             Jazan     3.0
# 17   Mortalities             Mecca   137.0
# 18   Mortalities            Medina    13.0
# 19   Mortalities  Northern Borders     2.0
# 20   Mortalities            Qassim     2.0
# 21   Mortalities            Riyadh    31.0
# 22   Mortalities             Tabuk     2.0
# 23    Recoveries          Al Bahah    37.0
# 24    Recoveries           Al Jouf    12.0
# 25    Recoveries              Asir   215.0
# 26    Recoveries    Eastern Region  3820.0
# 27    Recoveries              Hail    96.0
# 28    Recoveries             Jazan   237.0
# 29    Recoveries             Mecca  5055.0
# 30    Recoveries            Medina  4270.0
# 31    Recoveries            Najran    36.0
# 32    Recoveries  Northern Borders    32.0
# 33    Recoveries            Qassim   187.0
# 34    Recoveries            Riyadh  3349.0
# 35    Recoveries             Tabuk   358.0
# ------------ Groping Data for Type of Cases and Regions as Povit Style ------------
#                 Cases                 ...
# region       Al Bahah Al Jouf   Asir  ... Qassim  Riyadh  Tabuk
# Indicator                             ...
# Active cases      NaN     NaN    NaN  ...    NaN     NaN    NaN
# Cases            48.0    17.0  348.0  ...  395.0  7639.0  151.0
# Mortalities       NaN     NaN    2.0  ...    2.0    31.0    2.0
# Recoveries       37.0    12.0  215.0  ...  187.0  3349.0  358.0
#
# [4 rows x 13 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
